# %%
import pandas as pd
pd.set_option('display.max_columns', 25000)
pd.set_option('display.max_rows', 25000)
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
Df = pd.read_csv("MAT_alma_mater_top100_15countries.csv",sep=',')
Df_edu = pd.read_csv("eduCSV.csv",sep=',')
Df_merge = pd.merge(Df, Df_edu, left_on='wikidata_code_b', right_on='wikidata_code_B')
Df_merge.to_csv('merged.csv')

# %%
oxCol = "Oxford|Balliol College|Brasenose College|Christ Church|Corpus Christi College|Exeter College|Harris Manchester College|Hertford College|Jesus College|Keble College|Lady Margaret Hall|Lincoln College|Magdalen College|Mansfield College|Merton College|New College|Oriel College|Pembroke College|The Queen's College|Regent's Park College|St Anne's College|St Benet's Hall|St Catherine's College|St Edmund Hall|St Hilda's College|St Hugh's College|St John's College|St Peter's College|Somerville College|Trinity College|University College|Wadham College|Worcester College|Wycliffe Hall"
Df_merge
Df_merge[Df_merge['education'].str.contains("New York University|Tisch|Courant|CAS") == True]
# Out:
#    wikidata_code_b  living_people  birth_b  death_b gender_b final_occupation  \
# 19          Q41148              1     1942      NaN     Male     Culture-core
# 50          Q49001              1     1955      NaN   Female     Culture-core
# 61         Q170572              1     1958      NaN     Male     Culture-core
# 72         Q179497              1     1946      NaN     Male     Culture-core
# 84          Q51566              1     1957      NaN     Male     Culture-core
#
#     freq_final_second_occup final_second_occup  \
# 19                 0.057143            Missing
# 50                 0.041667            Missing
# 61                 0.090909            Missing
# 72                 0.035714            Missing
# 84                 0.000000            Missing
#
#                     bigperiod_birth_b  noccur_languages_b  ranking_final_b_5  \
# 19  5.Contemporary period 1901-2019AD                  81              219.0
# 50  5.Contemporary period 1901-2019AD                  76              634.5
# 61  5.Contemporary period 1901-2019AD                  67              859.0
# 72  5.Contemporary period 1901-2019AD                  61             1027.0
# 84  5.Contemporary period 1901-2019AD                  49             1149.0
#
#                                            keywords_b  \
# 19  P:_filmmaker_historian_crime_D:__film_actor_fi...
# 50  P:_actress_comedian_author_D:__actor_actor_rad...
# 61  P:__actor_writer_producer_D:__actor_actor_acto...
# 72  P:__writer_filmmaker_gangster_D:__film_screenw...
# 84  P:__film_producer_writer_D:__film_actor_screen...
#
#       list_areas_of_rattach area1_of_ratt area2_of_ratt           name_b  \
# 19  D:_'US'_matchB1_P:_'US'            US       Missing  Martin_Scorsese
# 50  D:_'US'_matchB1_P:_'US'            US       Missing  Whoopi_Goldberg
# 61  D:_'US'_matchB1_P:_'US'            US       Missing     Alec_Baldwin
# 72  D:_'US'_matchB1_P:_'US'            US       Missing     Oliver_Stone
# 84  D:_'US'_matchB1_P:_'US'            US       Missing        Spike_Lee
#
#                                         cleaned_sites  \
# 19  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...
# 50  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...
# 61  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...
# 72  enwiki|dewiki|frwiki|eswiki|ruwiki|itwiki|jawi...
# 84  enwiki|dewiki|frwiki|eswiki|ruwiki|jawiki|nlwi...
#
#                               cleaned_sites_long_name  un_subregion_new  \
# 19  English|German|French|Spanish|Russian|Italian|...  Northern America
# 50  English|German|French|Spanish|Russian|Italian|...  Northern America
# 61  English|German|French|Spanish|Russian|Italian|...  Northern America
# 72  English|German|French|Spanish|Russian|Italian|...  Northern America
# 84  English|German|French|Spanish|Russian|Japanese...  Northern America
#
#    UNregion_new  death_graph_b  birth_graph_b wikidata_code_B  \
# 19      America      2023.4607           1942          Q41148
# 50      America      2036.9064           1955          Q49001
# 61      America      2041.5453           1958         Q170572
# 72      America      2027.9683           1946         Q179497
# 84      America      2040.4106           1957          Q51566
#
#                                             education
# 19   ['New York University Tisch School of the Arts']
# 50                            ['New York University']
# 61  ['George Washington University', 'New York Uni...
# 72  ['New York University Tisch School of the Arts...
# 84  ['New York University Tisch School of the Arts...
